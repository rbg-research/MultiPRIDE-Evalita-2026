# %%
from src.baseline import get_bow_language_specific_baseline, get_bow_multilingual_baseline
from src.baseline import get_embeddings, get_embeddings_language_specific_baseline, get_embeddings_multilingual_baseline
# Out:
# ✓ All random seeds set to 42
# training files: ['train_en.csv', 'train_es.csv', 'train_it.csv']
# Total training samples: 2988
# ...
# CLASS DISTRIBUTION
# ...
#
# Overall:
#   Class 0 (NOT_RECLAMATORY): 2560 (85.7%)
#   Class 1 (RECLAMATORY): 428 (14.3%)
#   Total: 2988
#
# Per Language:
#   EN: Class 0=938, Class 1=88, Total=1026
#   ES: Class 0=743, Class 1=133, Total=876
#   IT: Class 0=879, Class 1=207, Total=1086

# %% [markdown]
# # 1. BoW + Conventional ML

# %% [markdown]
# ### Language Specific

# %%
get_bow_language_specific_baseline()
# Out:
# Performing StratifiedKFold 5 fold validation on language-specific datasets...
#
#  Best for EN: LogisticRegression (b) (Acc=0.515, Prec=0.598, Rec=0.515, F1=0.505)
#
#  Best for ES: LogisticRegression (b) (Acc=0.633, Prec=0.728, Rec=0.633, F1=0.660)
#
#  Best for IT: LogisticRegression (b) (Acc=0.780, Prec=0.909, Rec=0.780, F1=0.823)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 3        en  LogisticRegression (b)     0.515      0.598   0.515  0.505
# 1        en           LinearSVC (b)     0.511      0.525   0.511  0.497
# 0        en           LinearSVC (u)     0.500      0.457   0.500  0.478
# 2        en  LogisticRegression (u)     0.500      0.457   0.500  0.478
# 7        es  LogisticRegression (b)     0.633      0.728   0.633  0.660
# 5        es           LinearSVC (b)     0.600      0.846   0.600  0.628
# 4        es           LinearSVC (u)     0.547      0.860   0.547  0.547
# ...

# %% [markdown]
# ## Multi-Lingual

# %%
get_bow_multilingual_baseline()
# Out:
# Performing StratifiedKFold 5 fold validation on Multilingual Unified Dataset...
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.7149     0.7907  0.7149  0.7435
# 1  LogisticRegression (b)    0.7438     0.7266  0.7438  0.7340
# 2           LinearSVC (u)    0.6610     0.8601  0.6610  0.7077
# 3  LogisticRegression (u)    0.5275     0.8734  0.5275  0.5158
# * b -> balanced, u -> unbalanced

# %% [markdown]
# # 2. Embeddings + Conventional ML

# %% [markdown]
# ### Computing Embeddings

# %%
# get_embeddings()

# %% [markdown]
# ### Language Specific

# %%
get_embeddings_language_specific_baseline()
# Out:
# Embedding computed for the models: ['multilingual-e5-large', 'bge-m3', 'gte-multilingual-base', 'jina-embeddings-v3', 'snowflake-arctic-embed-l-v2.0', 'labse', 'use-multilingual', 'xlm-roberta-large']
#
# ...
# Evaluating embedding model: multilingual-e5-large
#
# ...
#
#  Best for EN: LinearSVC (b) (Acc=0.673, Prec=0.600, Rec=0.673, F1=0.619)
#
#  Best for ES: LinearSVC (b) (Acc=0.789, Prec=0.701, Rec=0.789, F1=0.726)
#
#  Best for IT: LinearSVC (u) (Acc=0.867, Prec=0.956, Rec=0.867, F1=0.902)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 9        en           LinearSVC (b)     0.673      0.600   0.673  0.619
# 11       en  LogisticRegression (b)     0.728      0.598   0.728  0.609
# 8        en           LinearSVC (u)     0.500      0.457   0.500  0.478
# 10       en  LogisticRegression (u)     0.500      0.457   0.500  0.478
# 1        es           LinearSVC (b)     0.789      0.701   0.789  0.726
# ...

# %% [markdown]
# ### Multi-Lingual

# %%
get_embeddings_multilingual_baseline()
# Out:
# ...
# Evaluating embedding model: multilingual-e5-large
#
# ...
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (u)    0.7018     0.8773  0.7018  0.7518
# 1           LinearSVC (b)    0.8018     0.7049  0.8018  0.7330
# 2  LogisticRegression (b)    0.7916     0.6846  0.7916  0.7094
# 3  LogisticRegression (u)    0.5553     0.8958  0.5553  0.5649
# * b -> balanced, u -> unbalanced
#
# ...
# Evaluating embedding model: bge-m3
#
# ...
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (u)    0.6965     0.8055  0.6965  0.7322
# 1           LinearSVC (b)    0.7789     0.7002  0.7789  0.7247
# 2  LogisticRegression (b)    0.7866     0.6874  0.7866  0.7125
# 3  LogisticRegression (u)    0.6346     0.8647  0.6346  0.6776
# * b -> balanced, u -> unbalanced
#
# ...
# Evaluating embedding model: gte-multilingual-base
#
# ...
#
# ...
