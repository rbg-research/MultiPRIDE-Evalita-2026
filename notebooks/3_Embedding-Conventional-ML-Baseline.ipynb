# %%
import gzip
import json
import numpy as np
import os
import pandas as pd
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from src.embeddings import ModelRegistry
from src.embeddings import EmbeddingPipeline
from src.utils import set_all_seeds

set_all_seeds()
# Out:
# ✓ All random seeds set to 42

# %%
considered_models = list(ModelRegistry.list_models().keys())
considered_models
# Out:
# ['multilingual-e5-large',
#  'bge-m3',
#  'gte-multilingual-base',
#  'jina-embeddings-v3',
#  'snowflake-arctic-embed-l-v2.0',
#  'labse',
#  'use-multilingual',
#  'xlm-roberta-large']

# %%
data_root = "../data/multipride_data/"
figures_root = "../figures/"
embeddings_root = "../embeddings/"
os.makedirs(figures_root, exist_ok=True)
os.makedirs(embeddings_root, exist_ok=True)

train_files = [file for file in os.listdir(data_root) if (file.endswith(".csv") and ("train" in file))]
train_files
# Out:
# ['train_en.csv', 'train_es.csv', 'train_it.csv']

# %%
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, zero_division=0),
    'recall': make_scorer(recall_score, zero_division=0),
    'f1': make_scorer(f1_score, zero_division=0)
}


models = {
    "LinearSVC (u)": LinearSVC(class_weight=None, max_iter=1000),
    "LinearSVC (b)": LinearSVC(class_weight='balanced', max_iter=1000),
    "LogisticRegression (u)": LogisticRegression(max_iter=500),
    "LogisticRegression (b)": LogisticRegression(class_weight='balanced', max_iter=500),
    "RandomForest (b)": RandomForestClassifier(class_weight='balanced', n_estimators=200),
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# # Language Specific - Baseline

# %%
for considered_model in considered_models:
    print(f"\n============================")
    print(f"Evaluating embedding model: {considered_model}")
    print(f"\n============================")
    embeddings_path = os.path.join(embeddings_root, considered_model + ".json.gz")
    with gzip.open(embeddings_path, 'rt', encoding='utf-8') as f:
        emb_data = json.load(f)
    feature_matrix = []
    labels = []
    text_ids = []
    langs = []
    for item in emb_data:
        text_ids.append(item)
        langs.append(item.split("_")[0])
        feature_matrix.append(emb_data[item]["emb"])
        labels.append(emb_data[item]["label"])

    train_df = pd.DataFrame.from_dict(
        {
            "ids": text_ids,
            "lang": langs,
            "feat": feature_matrix,
            "label": labels
        }
    )

    all_results = []

    df = train_df
    
    for lang in df['lang'].unique():
        
        lang_df = df[df['lang'] == lang]
        X = np.asarray(list(lang_df['feat']))
        labels = lang_df['label'].astype(int)
        
        for name, model in models.items():
            try:
                cv_results = cross_validate(model, X, labels, cv=cv, scoring=scoring)
                all_results.append({
                    'Language': lang,
                    'Model': name,
                    'Accuracy': np.mean(cv_results['test_accuracy']),
                    'Precision': np.mean(cv_results['test_precision']),
                    'Recall': np.mean(cv_results['test_recall']),
                    'F1': np.mean(cv_results['test_f1'])
                })
            except Exception as e:
                print(f"{name} failed for {lang}: {e}")
    
    
    results_df = pd.DataFrame(all_results)
    results_df = results_df.sort_values(['Language', 'F1'], ascending=[True, False])
    
    # Print best per language
    for lang in results_df['Language'].unique():
        best = results_df[results_df['Language'] == lang].iloc[0]
        print(f"\n Best for {lang.upper()}: {best['Model']} "
              f"(Acc={best['Accuracy']:.3f}, Prec={best['Precision']:.3f}, "
              f"Rec={best['Recall']:.3f}, F1={best['F1']:.3f})")
    
    print("\nAll Results Summary:\n", results_df.round(3))
    
    # --- Combined Average Score (across all languages) ---
    combined_avg = results_df[['Accuracy', 'Precision', 'Recall', 'F1']].mean()
    
    print("\nCombined Average Performance Across Languages:")
    print(f" Accuracy:  {combined_avg['Accuracy']:.3f}")
    print(f" Precision: {combined_avg['Precision']:.3f}")
    print(f" Recall:    {combined_avg['Recall']:.3f}")
    print(f" F1-score:  {combined_avg['F1']:.3f}")
# Out:
# ============================
# Evaluating embedding model: multilingual-e5-large
#
# ============================
#
#  Best for EN: LogisticRegression (b) (Acc=0.786, Prec=0.234, Rec=0.659, F1=0.346)
#
#  Best for ES: LinearSVC (b) (Acc=0.826, Prec=0.454, Rec=0.736, F1=0.561)
#
#  Best for IT: LinearSVC (u) (Acc=0.946, Prec=0.970, Rec=0.739, F1=0.837)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 13       en  LogisticRegression (b)     0.786      0.234   0.659  0.346
# 11       en           LinearSVC (b)     0.834      0.254   0.479  0.332
# 10       en           LinearSVC (u)     0.914      0.000   0.000  0.000
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.826      0.454   0.736  0.561
# 3        es  LogisticRegression (b)     0.799      0.418   0.811  0.551
# 0        es           LinearSVC (u)     0.871      0.720   0.255  0.374
# 4        es        RandomForest (b)     0.868      0.950   0.135  0.235
# 2        es  LogisticRegression (u)     0.848      0.000   0.000  0.000
# 5        it           LinearSVC (u)     0.946      0.970   0.739  0.837
# 6        it           LinearSVC (b)     0.904      0.705   0.865  0.775
# 8        it  LogisticRegression (b)     0.881      0.642   0.875  0.739
# 7        it  LogisticRegression (u)     0.884      0.990   0.397  0.555
# 9        it        RandomForest (b)     0.879      0.989   0.373  0.530
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.871
#  Precision: 0.488
#  Recall:    0.422
#  F1-score:  0.389
#
# ============================
# Evaluating embedding model: bge-m3
#
# ============================
#
#  Best for EN: LogisticRegression (b) (Acc=0.782, Prec=0.218, Rec=0.591, F1=0.318)
#
#  Best for ES: LinearSVC (b) (Acc=0.844, Prec=0.488, Rec=0.714, F1=0.578)
#
#  Best for IT: LinearSVC (u) (Acc=0.938, Prec=0.908, Rec=0.754, F1=0.823)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 13       en  LogisticRegression (b)     0.782      0.218   0.591  0.318
# 11       en           LinearSVC (b)     0.822      0.225   0.432  0.296
# 10       en           LinearSVC (u)     0.915      0.200   0.035  0.060
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.844      0.488   0.714  0.578
# 3        es  LogisticRegression (b)     0.815      0.438   0.759  0.554
# 0        es           LinearSVC (u)     0.882      0.663   0.442  0.528
# 4        es        RandomForest (b)     0.865      0.813   0.151  0.254
# 2        es  LogisticRegression (u)     0.865      0.810   0.151  0.251
# 5        it           LinearSVC (u)     0.938      0.908   0.754  0.823
# 6        it           LinearSVC (b)     0.917      0.759   0.841  0.795
# 8        it  LogisticRegression (b)     0.889      0.655   0.889  0.753
# 7        it  LogisticRegression (u)     0.920      0.925   0.633  0.749
# 9        it        RandomForest (b)     0.895      0.978   0.460  0.623
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.879
#  Precision: 0.539
#  Recall:    0.457
#  F1-score:  0.439
#
# ============================
# Evaluating embedding model: gte-multilingual-base
#
# ============================
#
#  Best for EN: LogisticRegression (b) (Acc=0.766, Prec=0.216, Rec=0.650, F1=0.323)
#
#  Best for ES: LinearSVC (b) (Acc=0.798, Prec=0.402, Rec=0.668, F1=0.498)
#
#  Best for IT: LinearSVC (u) (Acc=0.930, Prec=0.867, Rec=0.749, F1=0.803)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 13       en  LogisticRegression (b)     0.766      0.216   0.650  0.323
# 11       en           LinearSVC (b)     0.797      0.212   0.503  0.298
# 10       en           LinearSVC (u)     0.913      0.100   0.012  0.021
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.798      0.402   0.668  0.498
# 3        es  LogisticRegression (b)     0.768      0.373   0.751  0.496
# 0        es           LinearSVC (u)     0.868      0.631   0.316  0.419
# 4        es        RandomForest (b)     0.866      0.810   0.142  0.239
# 2        es  LogisticRegression (u)     0.852      0.700   0.045  0.085
# 5        it           LinearSVC (u)     0.930      0.867   0.749  0.803
# 6        it           LinearSVC (b)     0.910      0.726   0.865  0.787
# 8        it  LogisticRegression (b)     0.886      0.652   0.889  0.750
# 7        it  LogisticRegression (u)     0.913      0.926   0.595  0.723
# 9        it        RandomForest (b)     0.880      0.953   0.392  0.553
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.865
#  Precision: 0.504
#  Recall:    0.438
#  F1-score:  0.400
#
# ============================
# Evaluating embedding model: jina-embeddings-v3
#
# ============================
#
#  Best for EN: LogisticRegression (b) (Acc=0.754, Prec=0.206, Rec=0.637, F1=0.311)
#
#  Best for ES: LinearSVC (b) (Acc=0.825, Prec=0.454, Rec=0.698, F1=0.549)
#
#  Best for IT: LinearSVC (u) (Acc=0.932, Prec=0.864, Rec=0.769, F1=0.812)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 13       en  LogisticRegression (b)     0.754      0.206   0.637  0.311
# 11       en           LinearSVC (b)     0.784      0.204   0.524  0.294
# 10       en           LinearSVC (u)     0.913      0.000   0.000  0.000
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.825      0.454   0.698  0.549
# 3        es  LogisticRegression (b)     0.803      0.418   0.751  0.536
# 0        es           LinearSVC (u)     0.879      0.672   0.398  0.494
# 4        es        RandomForest (b)     0.872      0.807   0.202  0.320
# 2        es  LogisticRegression (u)     0.869      0.866   0.165  0.272
# 5        it           LinearSVC (u)     0.932      0.864   0.769  0.812
# 6        it           LinearSVC (b)     0.906      0.717   0.851  0.777
# 7        it  LogisticRegression (u)     0.917      0.886   0.648  0.748
# 8        it  LogisticRegression (b)     0.882      0.638   0.899  0.745
# 9        it        RandomForest (b)     0.889      0.914   0.455  0.602
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.870
#  Precision: 0.510
#  Recall:    0.466
#  F1-score:  0.431
#
# ============================
# Evaluating embedding model: snowflake-arctic-embed-l-v2.0
#
# ============================
#
#  Best for EN: LinearSVC (b) (Acc=0.833, Prec=0.266, Rec=0.501, F1=0.343)
#
#  Best for ES: LinearSVC (b) (Acc=0.839, Prec=0.479, Rec=0.698, F1=0.567)
#
#  Best for IT: LinearSVC (u) (Acc=0.942, Prec=0.905, Rec=0.788, F1=0.837)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 11       en           LinearSVC (b)     0.833      0.266   0.501  0.343
# 13       en  LogisticRegression (b)     0.773      0.223   0.660  0.333
# 10       en           LinearSVC (u)     0.914      0.500   0.035  0.064
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.839      0.479   0.698  0.567
# 3        es  LogisticRegression (b)     0.813      0.436   0.789  0.561
# 0        es           LinearSVC (u)     0.872      0.630   0.414  0.496
# 4        es        RandomForest (b)     0.870      0.813   0.187  0.299
# 2        es  LogisticRegression (u)     0.868      0.871   0.158  0.262
# 5        it           LinearSVC (u)     0.942      0.905   0.788  0.837
# 6        it           LinearSVC (b)     0.917      0.764   0.841  0.796
# 7        it  LogisticRegression (u)     0.930      0.942   0.677  0.784
# 8        it  LogisticRegression (b)     0.893      0.669   0.884  0.760
# 9        it        RandomForest (b)     0.897      0.939   0.493  0.640
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.879
#  Precision: 0.563
#  Recall:    0.475
#  F1-score:  0.450
#
# ============================
# Evaluating embedding model: labse
#
# ============================
#
#  Best for EN: LogisticRegression (b) (Acc=0.773, Prec=0.207, Rec=0.579, F1=0.305)
#
#  Best for ES: LinearSVC (b) (Acc=0.828, Prec=0.451, Rec=0.691, F1=0.543)
#
#  Best for IT: LinearSVC (u) (Acc=0.938, Prec=0.889, Rec=0.778, F1=0.828)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 13       en  LogisticRegression (b)     0.773      0.207   0.579  0.305
# 11       en           LinearSVC (b)     0.797      0.184   0.398  0.250
# 10       en           LinearSVC (u)     0.910      0.383   0.046  0.079
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.828      0.451   0.691  0.543
# 3        es  LogisticRegression (b)     0.791      0.401   0.744  0.519
# 0        es           LinearSVC (u)     0.866      0.602   0.337  0.430
# 2        es  LogisticRegression (u)     0.862      0.793   0.120  0.206
# 4        es        RandomForest (b)     0.855      0.800   0.060  0.111
# 5        it           LinearSVC (u)     0.938      0.889   0.778  0.828
# 6        it           LinearSVC (b)     0.920      0.759   0.865  0.806
# 8        it  LogisticRegression (b)     0.899      0.691   0.865  0.766
# 7        it  LogisticRegression (u)     0.914      0.890   0.628  0.735
# 9        it        RandomForest (b)     0.884      0.973   0.402  0.561
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.871
#  Precision: 0.535
#  Recall:    0.434
#  F1-score:  0.409
#
# ============================
# Evaluating embedding model: use-multilingual
#
# ============================
#
#  Best for EN: LinearSVC (b) (Acc=0.810, Prec=0.216, Rec=0.455, F1=0.293)
#
#  Best for ES: LinearSVC (b) (Acc=0.807, Prec=0.411, Rec=0.623, F1=0.493)
#
#  Best for IT: LinearSVC (u) (Acc=0.943, Prec=0.933, Rec=0.759, F1=0.835)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 11       en           LinearSVC (b)     0.810      0.216   0.455  0.293
# 13       en  LogisticRegression (b)     0.748      0.183   0.558  0.275
# 10       en           LinearSVC (u)     0.915      0.200   0.012  0.022
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.807      0.411   0.623  0.493
# 3        es  LogisticRegression (b)     0.777      0.377   0.699  0.487
# 0        es           LinearSVC (u)     0.874      0.659   0.338  0.440
# 4        es        RandomForest (b)     0.864      0.833   0.127  0.217
# 2        es  LogisticRegression (u)     0.856      0.686   0.120  0.197
# 5        it           LinearSVC (u)     0.943      0.933   0.759  0.835
# 6        it           LinearSVC (b)     0.925      0.781   0.860  0.816
# 8        it  LogisticRegression (b)     0.914      0.746   0.851  0.793
# 7        it  LogisticRegression (u)     0.921      0.924   0.638  0.752
# 9        it        RandomForest (b)     0.911      0.913   0.590  0.713
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.873
#  Precision: 0.524
#  Recall:    0.442
#  F1-score:  0.422
#
# ============================
# Evaluating embedding model: xlm-roberta-large
#
# ============================
#
#  Best for EN: LinearSVC (b) (Acc=0.633, Prec=0.143, Rec=0.649, F1=0.233)
#
#  Best for ES: LinearSVC (b) (Acc=0.767, Prec=0.358, Rec=0.662, F1=0.464)
#
#  Best for IT: LinearSVC (b) (Acc=0.857, Prec=0.604, Rec=0.739, F1=0.664)
#
# All Results Summary:
#     Language                   Model  Accuracy  Precision  Recall     F1
# 11       en           LinearSVC (b)     0.633      0.143   0.649  0.233
# 13       en  LogisticRegression (b)     0.596      0.135   0.671  0.224
# 10       en           LinearSVC (u)     0.914      0.000   0.000  0.000
# 12       en  LogisticRegression (u)     0.914      0.000   0.000  0.000
# 14       en        RandomForest (b)     0.914      0.000   0.000  0.000
# 1        es           LinearSVC (b)     0.767      0.358   0.662  0.464
# 3        es  LogisticRegression (b)     0.755      0.335   0.624  0.434
# 4        es        RandomForest (b)     0.856      0.900   0.060  0.111
# 0        es           LinearSVC (u)     0.848      0.000   0.000  0.000
# 2        es  LogisticRegression (u)     0.848      0.000   0.000  0.000
# 6        it           LinearSVC (b)     0.857      0.604   0.739  0.664
# 8        it  LogisticRegression (b)     0.822      0.527   0.667  0.588
# 9        it        RandomForest (b)     0.868      0.985   0.314  0.474
# 5        it           LinearSVC (u)     0.811      0.400   0.010  0.019
# 7        it  LogisticRegression (u)     0.809      0.000   0.000  0.000
#
# Combined Average Performance Across Languages:
#  Accuracy:  0.814
#  Precision: 0.292
#  Recall:    0.293
#  F1-score:  0.214

# %% [markdown]
# # Multi-Lingual Baseline

# %%
for considered_model in considered_models:
    print(f"\n============================")
    print(f"Evaluating embedding model: {considered_model}")
    print(f"\n============================")
    embeddings_path = os.path.join(embeddings_root, considered_model + ".json.gz")
    with gzip.open(embeddings_path, 'rt', encoding='utf-8') as f:
        emb_data = json.load(f)
    feature_matrix = []
    labels = []
    text_ids = []
    langs = []
    for item in emb_data:
        text_ids.append(item)
        langs.append(item.split("_")[0])
        feature_matrix.append(emb_data[item]["emb"])
        labels.append(emb_data[item]["label"])

    train_df = pd.DataFrame.from_dict(
        {
            "ids": text_ids,
            "lang": langs,
            "feat": feature_matrix,
            "label": labels
        }
    )

    X = np.asarray(list(train_df['feat']))
    labels = train_df['label'].astype(int)

    results = []

    for name, model in models.items():
        pipeline = Pipeline([('clf', model)])
        scores = cross_validate(pipeline, X, labels, cv=cv, scoring=scoring, n_jobs=-1)
        
        results.append({
            'Model': name,
            'Accuracy': np.mean(scores['test_accuracy']),
            'Precision': np.mean(scores['test_precision']),
            'Recall': np.mean(scores['test_recall']),
            'F1': np.mean(scores['test_f1'])
        })
    
    results_df = pd.DataFrame(results).sort_values(by='F1', ascending=False).reset_index(drop=True)
    
    
    print("\n Model Performance (Multilingual Unified Dataset):")
    print(results_df.round(4))
# Out:
# ============================
# Evaluating embedding model: multilingual-e5-large
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.8353     0.4559  0.7548  0.5678
# 1           LinearSVC (u)    0.9056     0.8446  0.4161  0.5563
# 2  LogisticRegression (b)    0.8112     0.4152  0.7641  0.5375
# 3  LogisticRegression (u)    0.8715     0.9211  0.1121  0.1998
# 4        RandomForest (b)    0.8678     0.8961  0.0865  0.1567
#
# ============================
# Evaluating embedding model: bge-m3
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.8360     0.4556  0.6989  0.5498
# 1  LogisticRegression (b)    0.8176     0.4239  0.7431  0.5389
# 2           LinearSVC (u)    0.8916     0.7014  0.4232  0.5257
# 3  LogisticRegression (u)    0.8889     0.8379  0.2781  0.4166
# 4        RandomForest (b)    0.8628     0.8129  0.0537  0.1005
#
# ============================
# Evaluating embedding model: gte-multilingual-base
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.8220     0.4278  0.7128  0.5340
# 1  LogisticRegression (b)    0.8012     0.3993  0.7641  0.5244
# 2           LinearSVC (u)    0.8922     0.7402  0.3833  0.5038
# 3  LogisticRegression (u)    0.8849     0.8685  0.2314  0.3644
# 4        RandomForest (b)    0.8641     0.8917  0.0585  0.1090
#
# ============================
# Evaluating embedding model: jina-embeddings-v3
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0  LogisticRegression (b)    0.8102     0.4130  0.7618  0.5353
# 1           LinearSVC (b)    0.8186     0.4240  0.7246  0.5333
# 2           LinearSVC (u)    0.8882     0.6846  0.4045  0.5069
# 3  LogisticRegression (u)    0.8866     0.7967  0.2760  0.4080
# 4        RandomForest (b)    0.8671     0.8511  0.0866  0.1565
#
# ============================
# Evaluating embedding model: snowflake-arctic-embed-l-v2.0
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.8393     0.4636  0.7501  0.5723
# 1           LinearSVC (u)    0.8996     0.7405  0.4629  0.5674
# 2  LogisticRegression (b)    0.8263     0.4402  0.7712  0.5601
# 3  LogisticRegression (u)    0.8949     0.8316  0.3344  0.4746
# 4        RandomForest (b)    0.8712     0.9291  0.1075  0.1918
#
# ============================
# Evaluating embedding model: labse
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.7992     0.3892  0.7056  0.5015
# 1  LogisticRegression (b)    0.7885     0.3783  0.7406  0.5007
# 2           LinearSVC (u)    0.8849     0.6743  0.3810  0.4856
# 3  LogisticRegression (u)    0.8795     0.7681  0.2268  0.3487
# 4        RandomForest (b)    0.8594     0.8000  0.0257  0.0497
#
# ============================
# Evaluating embedding model: use-multilingual
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.8176     0.4198  0.6800  0.5173
# 1  LogisticRegression (b)    0.8119     0.4087  0.7010  0.5154
# 2           LinearSVC (u)    0.8892     0.7072  0.3856  0.4974
# 3  LogisticRegression (u)    0.8896     0.8357  0.2850  0.4248
# 4        RandomForest (b)    0.8661     0.7814  0.0888  0.1586
#
# ============================
# Evaluating embedding model: xlm-roberta-large
#
# ============================
#
#  Model Performance (Multilingual Unified Dataset):
#                     Model  Accuracy  Precision  Recall      F1
# 0           LinearSVC (b)    0.7721     0.3485  0.6801  0.4607
# 1  LogisticRegression (b)    0.6650     0.2509  0.6707  0.3648
# 2        RandomForest (b)    0.8685     0.9800  0.0840  0.1534
# 3           LinearSVC (u)    0.8568     0.0000  0.0000  0.0000
# 4  LogisticRegression (u)    0.8568     0.0000  0.0000  0.0000
